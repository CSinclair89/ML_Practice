# %%
import tensorflow as tf
import pandas as pd
import datetime, warnings, scipy
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.rcParams["patch.force_edgecolor"] = True
plt.style.use("fivethirtyeight")
mpl.rc("patch", edgecolor = "dimgray", linewidth = 1)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"
pd.options.display.max_columns = 50
# %matplotlib inline
warnings.filterwarnings("ignore")
# Out:
# WARNING:tensorflow:From C:\Users\Chris\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import math

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error as mse

# %%
df = pd.read_csv("data/air_quality.csv", sep = " ")
df.head()
# Out:
#    No  Profile     Tanggal       Jam     O3    CO    NO2    SO2      NO  \
# 0   1  BANDUNG  2019-05-19  00:04:19  21.35  0.78   6.77  14.06  26.168
# 1   2  BANDUNG  2019-05-19  00:15:01   5.93  0.82  14.87  17.23  53.853
# 2   3  BANDUNG  2019-05-19  00:30:06   6.62  0.63  22.24   2.31  38.304
# 3   4  BANDUNG  2019-05-19  00:49:19  13.29  0.44  19.00   5.32  18.962
# 4   5  BANDUNG  2019-05-19  01:04:19   2.44  0.47  26.74  13.61  35.270
#
#       CO2      VOC  PM1  PM2.5  PM4   PM10  TSP  TEMP    HUM     WS  WD  ISPU  \
# 0  409.86  251.202  0.0    0.0  0.0   2.77  0.0  21.4  100.0  0.600   5     9
# 1  394.79  501.356  0.0    0.0  0.0  11.95  0.0  42.6  200.0  0.000   2    12
# 2  390.66  753.291  0.0    0.0  0.0  12.71  0.0  63.6  299.2  0.000   2    13
# 3  401.23  251.043  0.0    0.0  0.0   1.20  0.0  21.3   88.2  0.525   5     6
# 4  381.67  250.471  0.0    0.0  0.0   3.52  0.0  21.3   97.4  0.975   5     9
#
#   Status  Unnamed: 22
# 0   BAIK          NaN
# 1   BAIK          NaN
# 2   BAIK          NaN
# 3   BAIK          NaN
# 4   BAIK          NaN

# %%
# Convert Time ("Tanggal") to datetime format

def combine_date(df, tab_name):
    list_tab = []
    for i in range(df.shape[0]):
        list_tab.append(df.loc[i, "Tanggal"] + "T" + df.loc[i, tab_name][0:2])
    return np.array(list_tab, dtype = "datetime64")

# convert TME to datetime format
df["Datetime"] = combine_date(df, "Jam")

# Convert into hourly data

df = df[["Datetime", "O3", "CO", "NO2", "SO2", "NO", "CO2", "VOC", "PM1", "PM2.5", "PM4", "PM10", "TSP", "TEMP", "HUM", "WS", "WD", "ISPU"]]

df2 = df.groupby(["Datetime"]).mean()
df2.head()
# Out:
#                             O3        CO     NO2      SO2        NO  \
# Datetime
# 2019-05-19 00:00:00  11.797500  0.667500  15.720   9.7300  34.32175
# 2019-05-19 01:00:00   3.816667  0.373333  22.600  20.0900  39.82100
# 2019-05-19 02:00:00   6.450000  0.332500  24.130  26.3100  51.29325
# 2019-05-19 03:00:00   4.740000  0.180000  25.975  24.3900  43.51850
# 2019-05-19 04:00:00  19.692500  0.202500  20.395  18.6225  53.37925
#
#                             CO2        VOC  PM1  PM2.5  PM4      PM10  TSP  \
# Datetime
# 2019-05-19 00:00:00  399.135000  439.22300  0.0    0.0  0.0  7.157500  0.0
# 2019-05-19 01:00:00  388.536667  250.39400  0.0    0.0  0.0  3.293333  0.0
# 2019-05-19 02:00:00  396.242500  251.04575  0.0    0.0  0.0  6.487500  0.0
# 2019-05-19 03:00:00  401.355000  252.24875  0.0    0.0  0.0  4.700000  0.0
# 2019-05-19 04:00:00  399.335000  694.23975  0.0    0.0  0.0  5.262500  0.0
#
#                           TEMP         HUM       WS        WD       ISPU
# Datetime
# 2019-05-19 00:00:00  37.225000  171.850000  0.28125  3.500000  10.000000
# 2019-05-19 01:00:00  20.966667   95.033333  0.67500  4.666667  12.666667
# 2019-05-19 02:00:00  20.150000   97.500000  0.09375  3.750000  16.250000
# 2019-05-19 03:00:00  19.850000  100.000000  0.07500  5.000000  15.000000
# 2019-05-19 04:00:00  53.475000  272.500000  0.18750  5.250000  13.250000

# %%
df2.describe()
# Out:
#                 O3           CO          NO2          SO2           NO  \
# count  1737.000000  1737.000000  1737.000000  1737.000000  1737.000000
# mean      8.538909     0.233172    16.681910    12.013894    37.086256
# std       3.997292     0.388102     5.373487     4.411251    12.521778
# min       0.270000     0.010000     2.040000     2.162500     3.128750
# 25%       5.881667     0.083333    13.010000     9.015000    28.443500
# 50%       7.813333     0.160000    15.916667    11.730000    39.252250
# 75%      10.373333     0.296667    19.935000    14.595000    46.015500
# max      33.741667    13.950000    99.600000    46.290000   194.554000
#
#                CO2          VOC          PM1        PM2.5          PM4  \
# count  1737.000000  1737.000000  1737.000000  1737.000000  1737.000000
# mean    394.616480   260.053778     0.309564     0.383692     0.451982
# std       4.180224    60.773321     2.286104     2.874126     3.378291
# min     380.420000   187.518000     0.000000     0.000000     0.000000
# 25%     391.830000   247.798333     0.000000     0.000000     0.000000
# 50%     394.602000   250.926250     0.000000     0.000000     0.000000
# 75%     397.415000   253.286667     0.000000     0.000000     0.000000
# max     408.820000  1240.713500    51.600000    68.700000    79.800000
#
#               PM10          TSP         TEMP          HUM           WS  \
# count  1737.000000  1737.000000  1737.000000  1737.000000  1737.000000
# mean      6.157770     0.562012    25.266942    77.634191    24.291226
# std       4.149511     4.184787     6.707977    29.743129    51.993683
# min       0.885000     0.000000    11.250000    26.866667     0.000000
# 25%       4.340000     0.000000    21.266667    57.850000     0.237500
# 50%       5.571667     0.000000    24.100000    77.083333     1.312500
# 75%       7.090000     0.000000    28.400000    94.066667     5.075000
# max      91.600000    92.900000   124.600000   313.400000   199.200000
#
#                 WD         ISPU
# count  1737.000000  1737.000000
# mean      7.129031    10.097848
# std       3.523245     5.049788
# min       0.000000     4.250000
# 25%       4.666667     8.166667
# 50%       5.833333     9.500000
# 75%      10.500000    11.000000
# max      15.000000   156.500000

# %%
# Calculate the quantile for each variable

def calculate_quant (i, df2):
    Q1 = df2[[i]].quantile(0.25)[0]
    Q3 = df2[[i]].quantile(0.75)[0]
    IQR = Q3 - Q1
    min = df2[[i]].min()[0]
    max = df2[[i]].max()[0]
    min_IQR = Q1 - 1.5 * IQR
    max_IQR = Q3 + 1.5 * IQR
    return Q1, Q3, min, max, min_IQR, max_IQR

# delete first and last rows to avoid missing value extrapolation
df2.drop(index=[df2.index[0], df2.index[df2.shape[0] - 1]], inplace = True)

for i in df2.columns:
    print ("\nAttribute-", i, ":")
    Q1, Q3, min, max, min_IQR, max_IQR = calculate_quant(i, df2)
    print("Q1 = %.2f" % Q1)
    print("Q3 = %.2f" % Q3)
    print("min IQR = %.2f" % min_IQR)
    print("max IQR = %.2f" % max_IQR)
    if (min < min_IQR):
        print("---> Low outlier is found = %.2f" % min)
    if (max > max_IQR):
        print("---> High outlier is found = %.2f" % max)
        
    def convert_nan (x, max_IQR = max_IQR, min_IQR = min_IQR):
        if ((x > max_IQR) | (x < min_IQR)):
            x = np.nan
        else:
            x = x
        return x

    def convert_nan_HUM (x, max_IQR = 100.0, min_IQR = min_IQR):
        if ((x > max_IQR) | (x < min_IQR)):
            x = np.nan
        else:
            x = x
        return x
    
    if (i == "HUM"):
        df2[i] = df2[i].map(convert_nan_HUM)
        df2[i] = df2[i].interpolate(method = "linear")
    if (i != "HUM"):
        df2[i] = df2[i].map(convert_nan)
        df2[i] = df2[i].interpolate(method = "linear")
        
    if (len(df2[df2[i].isnull()][i]) == 0):
        print("##### Outliers have been interpolated #####")
# Out:
# Attribute- O3 :
# Q1 = 5.87
# Q3 = 10.26
# min IQR = -0.72
# max IQR = 16.85
# ##### Outliers have been interpolated #####
#
# Attribute- CO :
# Q1 = 0.08
# Q3 = 0.29
# min IQR = -0.23
# max IQR = 0.61
# ##### Outliers have been interpolated #####
#
# Attribute- NO2 :
# Q1 = 12.98
# Q3 = 19.77
# min IQR = 2.79
# max IQR = 29.96
# ##### Outliers have been interpolated #####
#
# Attribute- SO2 :
# Q1 = 8.98
# Q3 = 14.48
# min IQR = 0.73
# max IQR = 22.73
# ##### Outliers have been interpolated #####
#
# Attribute- NO :
# Q1 = 28.38
# Q3 = 46.00
# min IQR = 1.95
# max IQR = 72.42
# ##### Outliers have been interpolated #####
#
# Attribute- CO2 :
# Q1 = 391.86
# Q3 = 397.39
# min IQR = 383.57
# max IQR = 405.69
# ##### Outliers have been interpolated #####
#
# Attribute- VOC :
# Q1 = 247.88
# Q3 = 253.02
# min IQR = 240.19
# max IQR = 260.71
# ##### Outliers have been interpolated #####
#
# Attribute- PM1 :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ##### Outliers have been interpolated #####
#
# Attribute- PM2.5 :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ##### Outliers have been interpolated #####
#
# Attribute- PM4 :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ##### Outliers have been interpolated #####
#
# Attribute- PM10 :
# Q1 = 4.31
# Q3 = 6.88
# min IQR = 0.45
# max IQR = 10.73
# ##### Outliers have been interpolated #####
#
# Attribute- TSP :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ##### Outliers have been interpolated #####
#
# Attribute- TEMP :
# Q1 = 21.21
# Q3 = 28.08
# min IQR = 10.91
# max IQR = 38.39
# ##### Outliers have been interpolated #####
#
# Attribute- HUM :
# Q1 = 57.67
# Q3 = 92.12
# min IQR = 5.98
# max IQR = 143.81
# ##### Outliers have been interpolated #####
#
# Attribute- WS :
# Q1 = 0.24
# Q3 = 3.51
# min IQR = -4.67
# max IQR = 8.42
# ##### Outliers have been interpolated #####
#
# Attribute- WD :
# Q1 = 4.67
# Q3 = 10.67
# min IQR = -4.33
# max IQR = 19.67
# ##### Outliers have been interpolated #####
#
# Attribute- ISPU :
# Q1 = 8.17
# Q3 = 10.83
# min IQR = 4.17
# max IQR = 14.83
# ##### Outliers have been interpolated #####

# %%
# Log transform to deal with skewed data

dataset = np.log1p(df2[["TEMP"]].values)
dataset.shape
# Out:
# (1735, 1)

# %%
dist_df = pd.DataFrame({"TEMP" : df2["TEMP"].values, "log_TEMP" : dataset[:, 0]})

# Histogram plot original vs. log transform
plt.figure(figsize = (12, 5))
dist_df.hist();

# %%
# Split dataset into train/test sets

train_size = int(len(dataset) * 0.75)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 1301 434

# %%
# Convert array of values into dataset matrix

def create_dataset(dataset, look_back = 1):
    dataX, dataY = [], []
    for i in range (len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# Reshape train/test data

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

print("Shape of trainX: ", trainX.shape)
print("Shape of trainY: ", trainY.shape)
print("Shape of testX: ", testX.shape)
print("Shape of testY: ", testY.shape)
# Out:
# Shape of trainX:  (1299, 1)
# Shape of trainY:  (1299,)
# Shape of testX:  (432, 1)
# Shape of testY:  (432,)

# %%
# Reshape input array in the form - [samples, time steps, features]

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

print("Shape of trainX: ", trainX.shape)
print("Shape of testX: ", testX.shape)
# Out:
# Shape of trainX:  (1299, 1, 1)
# Shape of testX:  (432, 1, 1)

# %%
# Create and fit LSTM neural network

model = Sequential()
model.add(LSTM(4, input_shape = (1, look_back)))
model.add(Dense(1))

model.compile(loss = "mse", optimizer = "adam")
model.fit(trainX, trainY, epochs = 500, batch_size = 32, verbose = 2)
# Out:
# WARNING:tensorflow:From C:\Users\Chris\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Chris\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/500
# WARNING:tensorflow:From C:\Users\Chris\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 41/41 - 1s - loss: 9.5238 - 1s/epoch - 28ms/step
# Epoch 2/500
# 41/41 - 0s - loss: 8.8945 - 33ms/epoch - 806us/step
# Epoch 3/500
# 41/41 - 0s - loss: 8.2630 - 34ms/epoch - 830us/step
# Epoch 4/500
# 41/41 - 0s - loss: 7.6165 - 35ms/epoch - 854us/step
# Epoch 5/500
# 41/41 - 0s - loss: 6.9555 - 33ms/epoch - 806us/step
# Epoch 6/500
# 41/41 - 0s - loss: 6.2906 - 35ms/epoch - 854us/step
# Epoch 7/500
# 41/41 - 0s - loss: 5.6357 - 35ms/epoch - 854us/step
# Epoch 8/500
# 41/41 - 0s - loss: 5.0050 - 34ms/epoch - 830us/step
# Epoch 9/500
# 41/41 - 0s - loss: 4.4078 - 35ms/epoch - 854us/step
# Epoch 10/500
# 41/41 - 0s - loss: 3.8466 - 34ms/epoch - 830us/step
# Epoch 11/500
# 41/41 - 0s - loss: 3.3113 - 35ms/epoch - 854us/step
# Epoch 12/500
# 41/41 - 0s - loss: 2.7779 - 35ms/epoch - 854us/step
# Epoch 13/500
# 41/41 - 0s - loss: 2.2108 - 35ms/epoch - 854us/step
# Epoch 14/500
# 41/41 - 0s - loss: 1.6065 - 36ms/epoch - 879us/step
# Epoch 15/500
# 41/41 - 0s - loss: 1.0309 - 38ms/epoch - 928us/step
# Epoch 16/500
# 41/41 - 0s - loss: 0.5799 - 36ms/epoch - 879us/step
# Epoch 17/500
# 41/41 - 0s - loss: 0.2950 - 37ms/epoch - 903us/step
# Epoch 18/500
# 41/41 - 0s - loss: 0.1428 - 37ms/epoch - 903us/step
# Epoch 19/500
# 41/41 - 0s - loss: 0.0710 - 37ms/epoch - 903us/step
# Epoch 20/500
# 41/41 - 0s - loss: 0.0392 - 37ms/epoch - 903us/step
# Epoch 21/500
# 41/41 - 0s - loss: 0.0262 - 34ms/epoch - 830us/step
# Epoch 22/500
# 41/41 - 0s - loss: 0.0210 - 35ms/epoch - 854us/step
# Epoch 23/500
# 41/41 - 0s - loss: 0.0191 - 34ms/epoch - 830us/step
# Epoch 24/500
# 41/41 - 0s - loss: 0.0184 - 34ms/epoch - 830us/step
# Epoch 25/500
# 41/41 - 0s - loss: 0.0182 - 35ms/epoch - 854us/step
# Epoch 26/500
# 41/41 - 0s - loss: 0.0181 - 34ms/epoch - 830us/step
# Epoch 27/500
# 41/41 - 0s - loss: 0.0181 - 33ms/epoch - 806us/step
# Epoch 28/500
# 41/41 - 0s - loss: 0.0180 - 34ms/epoch - 830us/step
# Epoch 29/500
# 41/41 - 0s - loss: 0.0180 - 35ms/epoch - 854us/step
# Epoch 30/500
# 41/41 - 0s - loss: 0.0180 - 36ms/epoch - 879us/step
# Epoch 31/500
# 41/41 - 0s - loss: 0.0180 - 35ms/epoch - 854us/step
# Epoch 32/500
# 41/41 - 0s - loss: 0.0180 - 35ms/epoch - 854us/step
# Epoch 33/500
# 41/41 - 0s - loss: 0.0180 - 34ms/epoch - 830us/step
# Epoch 34/500
# 41/41 - 0s - loss: 0.0180 - 35ms/epoch - 854us/step
# Epoch 35/500
# 41/41 - 0s - loss: 0.0180 - 35ms/epoch - 854us/step
# Epoch 36/500
# 41/41 - 0s - loss: 0.0180 - 34ms/epoch - 830us/step
# Epoch 37/500
# 41/41 - 0s - loss: 0.0179 - 35ms/epoch - 854us/step
# Epoch 38/500
# 41/41 - 0s - loss: 0.0179 - 34ms/epoch - 830us/step
# Epoch 39/500
# 41/41 - 0s - loss: 0.0179 - 34ms/epoch - 830us/step
# Epoch 40/500
# 41/41 - 0s - loss: 0.0179 - 34ms/epoch - 830us/step
# Epoch 41/500
# 41/41 - 0s - loss: 0.0179 - 34ms/epoch - 830us/step
# Epoch 42/500
# 41/41 - 0s - loss: 0.0179 - 35ms/epoch - 854us/step
# Epoch 43/500
# 41/41 - 0s - loss: 0.0179 - 35ms/epoch - 854us/step
# Epoch 44/500
# 41/41 - 0s - loss: 0.0179 - 34ms/epoch - 830us/step
# Epoch 45/500
# 41/41 - 0s - loss: 0.0178 - 35ms/epoch - 854us/step
# Epoch 46/500
# 41/41 - 0s - loss: 0.0178 - 34ms/epoch - 830us/step
# Epoch 47/500
# 41/41 - 0s - loss: 0.0178 - 34ms/epoch - 830us/step
# Epoch 48/500
# 41/41 - 0s - loss: 0.0178 - 35ms/epoch - 854us/step
# Epoch 49/500
# 41/41 - 0s - loss: 0.0178 - 34ms/epoch - 830us/step
# Epoch 50/500
# 41/41 - 0s - loss: 0.0177 - 34ms/epoch - 830us/step
# Epoch 51/500
# 41/41 - 0s - loss: 0.0177 - 34ms/epoch - 830us/step
# Epoch 52/500
# 41/41 - 0s - loss: 0.0177 - 34ms/epoch - 830us/step
# Epoch 53/500
# 41/41 - 0s - loss: 0.0177 - 35ms/epoch - 854us/step
# Epoch 54/500
# 41/41 - 0s - loss: 0.0177 - 35ms/epoch - 854us/step
# Epoch 55/500
# 41/41 - 0s - loss: 0.0177 - 33ms/epoch - 806us/step
# Epoch 56/500
# 41/41 - 0s - loss: 0.0176 - 34ms/epoch - 830us/step
# Epoch 57/500
# 41/41 - 0s - loss: 0.0176 - 34ms/epoch - 830us/step
# Epoch 58/500
# 41/41 - 0s - loss: 0.0176 - 34ms/epoch - 830us/step
# Epoch 59/500
# 41/41 - 0s - loss: 0.0176 - 34ms/epoch - 830us/step
# Epoch 60/500
# 41/41 - 0s - loss: 0.0176 - 35ms/epoch - 854us/step
# Epoch 61/500
# 41/41 - 0s - loss: 0.0175 - 34ms/epoch - 830us/step
# Epoch 62/500
# 41/41 - 0s - loss: 0.0175 - 35ms/epoch - 854us/step
# Epoch 63/500
# 41/41 - 0s - loss: 0.0175 - 34ms/epoch - 830us/step
# Epoch 64/500
# 41/41 - 0s - loss: 0.0175 - 34ms/epoch - 830us/step
# Epoch 65/500
# 41/41 - 0s - loss: 0.0174 - 35ms/epoch - 854us/step
# Epoch 66/500
# 41/41 - 0s - loss: 0.0174 - 34ms/epoch - 830us/step
# Epoch 67/500
# 41/41 - 0s - loss: 0.0174 - 34ms/epoch - 830us/step
# Epoch 68/500
# 41/41 - 0s - loss: 0.0174 - 34ms/epoch - 830us/step
# Epoch 69/500
# 41/41 - 0s - loss: 0.0173 - 35ms/epoch - 854us/step
# Epoch 70/500
# 41/41 - 0s - loss: 0.0173 - 35ms/epoch - 854us/step
# Epoch 71/500
# 41/41 - 0s - loss: 0.0173 - 34ms/epoch - 830us/step
# Epoch 72/500
# 41/41 - 0s - loss: 0.0173 - 34ms/epoch - 830us/step
# Epoch 73/500
# 41/41 - 0s - loss: 0.0172 - 34ms/epoch - 830us/step
# Epoch 74/500
# 41/41 - 0s - loss: 0.0172 - 34ms/epoch - 830us/step
# Epoch 75/500
# 41/41 - 0s - loss: 0.0172 - 34ms/epoch - 830us/step
# Epoch 76/500
# 41/41 - 0s - loss: 0.0171 - 35ms/epoch - 854us/step
# Epoch 77/500
# 41/41 - 0s - loss: 0.0171 - 35ms/epoch - 854us/step
# Epoch 78/500
# 41/41 - 0s - loss: 0.0171 - 34ms/epoch - 830us/step
# Epoch 79/500
# 41/41 - 0s - loss: 0.0170 - 34ms/epoch - 830us/step
# Epoch 80/500
# 41/41 - 0s - loss: 0.0170 - 33ms/epoch - 806us/step
# Epoch 81/500
# 41/41 - 0s - loss: 0.0170 - 34ms/epoch - 830us/step
# Epoch 82/500
# 41/41 - 0s - loss: 0.0169 - 33ms/epoch - 806us/step
# Epoch 83/500
# 41/41 - 0s - loss: 0.0169 - 33ms/epoch - 806us/step
# Epoch 84/500
# 41/41 - 0s - loss: 0.0169 - 33ms/epoch - 806us/step
# Epoch 85/500
# 41/41 - 0s - loss: 0.0168 - 34ms/epoch - 830us/step
# Epoch 86/500
# 41/41 - 0s - loss: 0.0168 - 34ms/epoch - 830us/step
# Epoch 87/500
# 41/41 - 0s - loss: 0.0167 - 34ms/epoch - 830us/step
# Epoch 88/500
# 41/41 - 0s - loss: 0.0167 - 34ms/epoch - 830us/step
# Epoch 89/500
# 41/41 - 0s - loss: 0.0167 - 34ms/epoch - 830us/step
# Epoch 90/500
# 41/41 - 0s - loss: 0.0166 - 34ms/epoch - 830us/step
# Epoch 91/500
# 41/41 - 0s - loss: 0.0166 - 33ms/epoch - 806us/step
# Epoch 92/500
# 41/41 - 0s - loss: 0.0165 - 35ms/epoch - 854us/step
# Epoch 93/500
# 41/41 - 0s - loss: 0.0165 - 34ms/epoch - 830us/step
# Epoch 94/500
# 41/41 - 0s - loss: 0.0164 - 34ms/epoch - 830us/step
# Epoch 95/500
# 41/41 - 0s - loss: 0.0164 - 35ms/epoch - 854us/step
# Epoch 96/500
# 41/41 - 0s - loss: 0.0163 - 33ms/epoch - 806us/step
# Epoch 97/500
# 41/41 - 0s - loss: 0.0163 - 33ms/epoch - 806us/step
# Epoch 98/500
# 41/41 - 0s - loss: 0.0162 - 34ms/epoch - 830us/step
# Epoch 99/500
# 41/41 - 0s - loss: 0.0162 - 35ms/epoch - 854us/step
# Epoch 100/500
# 41/41 - 0s - loss: 0.0161 - 34ms/epoch - 830us/step
# Epoch 101/500
# 41/41 - 0s - loss: 0.0161 - 34ms/epoch - 818us/step
# Epoch 102/500
# 41/41 - 0s - loss: 0.0160 - 33ms/epoch - 806us/step
# Epoch 103/500
# 41/41 - 0s - loss: 0.0159 - 33ms/epoch - 806us/step
# Epoch 104/500
# 41/41 - 0s - loss: 0.0159 - 33ms/epoch - 806us/step
# Epoch 105/500
# 41/41 - 0s - loss: 0.0158 - 34ms/epoch - 830us/step
# Epoch 106/500
# 41/41 - 0s - loss: 0.0158 - 34ms/epoch - 830us/step
# Epoch 107/500
# 41/41 - 0s - loss: 0.0157 - 33ms/epoch - 806us/step
# Epoch 108/500
# 41/41 - 0s - loss: 0.0156 - 34ms/epoch - 830us/step
# Epoch 109/500
# 41/41 - 0s - loss: 0.0156 - 34ms/epoch - 830us/step
# Epoch 110/500
# 41/41 - 0s - loss: 0.0155 - 33ms/epoch - 806us/step
# Epoch 111/500
# 41/41 - 0s - loss: 0.0154 - 33ms/epoch - 806us/step
# Epoch 112/500
# 41/41 - 0s - loss: 0.0153 - 34ms/epoch - 830us/step
# Epoch 113/500
# 41/41 - 0s - loss: 0.0153 - 33ms/epoch - 806us/step
# Epoch 114/500
# 41/41 - 0s - loss: 0.0152 - 33ms/epoch - 806us/step
# Epoch 115/500
# 41/41 - 0s - loss: 0.0151 - 34ms/epoch - 830us/step
# Epoch 116/500
# 41/41 - 0s - loss: 0.0151 - 34ms/epoch - 830us/step
# Epoch 117/500
# 41/41 - 0s - loss: 0.0150 - 34ms/epoch - 830us/step
# Epoch 118/500
# 41/41 - 0s - loss: 0.0149 - 34ms/epoch - 830us/step
# Epoch 119/500
# 41/41 - 0s - loss: 0.0149 - 34ms/epoch - 830us/step
# Epoch 120/500
# 41/41 - 0s - loss: 0.0148 - 34ms/epoch - 830us/step
# Epoch 121/500
# 41/41 - 0s - loss: 0.0147 - 34ms/epoch - 830us/step
# Epoch 122/500
# 41/41 - 0s - loss: 0.0145 - 33ms/epoch - 806us/step
# Epoch 123/500
# 41/41 - 0s - loss: 0.0145 - 34ms/epoch - 830us/step
# Epoch 124/500
# 41/41 - 0s - loss: 0.0144 - 34ms/epoch - 830us/step
# Epoch 125/500
# 41/41 - 0s - loss: 0.0143 - 34ms/epoch - 830us/step
# Epoch 126/500
# 41/41 - 0s - loss: 0.0142 - 33ms/epoch - 806us/step
# Epoch 127/500
# 41/41 - 0s - loss: 0.0141 - 34ms/epoch - 830us/step
# Epoch 128/500
# 41/41 - 0s - loss: 0.0140 - 34ms/epoch - 830us/step
# Epoch 129/500
# 41/41 - 0s - loss: 0.0139 - 35ms/epoch - 854us/step
# Epoch 130/500
# 41/41 - 0s - loss: 0.0138 - 34ms/epoch - 830us/step
# Epoch 131/500
# 41/41 - 0s - loss: 0.0137 - 35ms/epoch - 854us/step
# Epoch 132/500
# 41/41 - 0s - loss: 0.0136 - 34ms/epoch - 830us/step
# Epoch 133/500
# 41/41 - 0s - loss: 0.0135 - 33ms/epoch - 806us/step
# Epoch 134/500
# 41/41 - 0s - loss: 0.0134 - 34ms/epoch - 830us/step
# Epoch 135/500
# 41/41 - 0s - loss: 0.0133 - 33ms/epoch - 806us/step
# Epoch 136/500
# 41/41 - 0s - loss: 0.0131 - 34ms/epoch - 830us/step
# Epoch 137/500
# 41/41 - 0s - loss: 0.0129 - 34ms/epoch - 830us/step
# Epoch 138/500
# 41/41 - 0s - loss: 0.0128 - 34ms/epoch - 830us/step
# Epoch 139/500
# 41/41 - 0s - loss: 0.0127 - 33ms/epoch - 806us/step
# Epoch 140/500
# 41/41 - 0s - loss: 0.0125 - 34ms/epoch - 830us/step
# Epoch 141/500
# 41/41 - 0s - loss: 0.0123 - 34ms/epoch - 830us/step
# Epoch 142/500
# 41/41 - 0s - loss: 0.0121 - 34ms/epoch - 830us/step
# Epoch 143/500
# 41/41 - 0s - loss: 0.0119 - 33ms/epoch - 806us/step
# Epoch 144/500
# 41/41 - 0s - loss: 0.0118 - 34ms/epoch - 830us/step
# Epoch 145/500
# 41/41 - 0s - loss: 0.0115 - 34ms/epoch - 830us/step
# Epoch 146/500
# 41/41 - 0s - loss: 0.0113 - 34ms/epoch - 830us/step
# Epoch 147/500
# 41/41 - 0s - loss: 0.0112 - 34ms/epoch - 830us/step
# Epoch 148/500
# 41/41 - 0s - loss: 0.0109 - 33ms/epoch - 806us/step
# Epoch 149/500
# 41/41 - 0s - loss: 0.0108 - 34ms/epoch - 830us/step
# Epoch 150/500
# 41/41 - 0s - loss: 0.0106 - 34ms/epoch - 830us/step
# Epoch 151/500
# 41/41 - 0s - loss: 0.0105 - 34ms/epoch - 830us/step
# Epoch 152/500
# 41/41 - 0s - loss: 0.0103 - 33ms/epoch - 806us/step
# Epoch 153/500
# 41/41 - 0s - loss: 0.0102 - 34ms/epoch - 830us/step
# Epoch 154/500
# 41/41 - 0s - loss: 0.0101 - 34ms/epoch - 830us/step
# Epoch 155/500
# 41/41 - 0s - loss: 0.0101 - 33ms/epoch - 806us/step
# Epoch 156/500
# 41/41 - 0s - loss: 0.0100 - 33ms/epoch - 806us/step
# Epoch 157/500
# 41/41 - 0s - loss: 0.0098 - 35ms/epoch - 854us/step
# Epoch 158/500
# 41/41 - 0s - loss: 0.0098 - 35ms/epoch - 854us/step
# Epoch 159/500
# 41/41 - 0s - loss: 0.0098 - 35ms/epoch - 854us/step
# Epoch 160/500
# 41/41 - 0s - loss: 0.0097 - 34ms/epoch - 830us/step
# Epoch 161/500
# 41/41 - 0s - loss: 0.0096 - 34ms/epoch - 830us/step
# Epoch 162/500
# 41/41 - 0s - loss: 0.0095 - 33ms/epoch - 806us/step
# Epoch 163/500
# 41/41 - 0s - loss: 0.0095 - 34ms/epoch - 830us/step
# Epoch 164/500
# 41/41 - 0s - loss: 0.0094 - 34ms/epoch - 830us/step
# Epoch 165/500
# 41/41 - 0s - loss: 0.0094 - 34ms/epoch - 830us/step
# Epoch 166/500
# 41/41 - 0s - loss: 0.0094 - 35ms/epoch - 854us/step
# Epoch 167/500
# 41/41 - 0s - loss: 0.0093 - 34ms/epoch - 830us/step
# Epoch 168/500
# 41/41 - 0s - loss: 0.0094 - 34ms/epoch - 830us/step
# Epoch 169/500
# 41/41 - 0s - loss: 0.0093 - 35ms/epoch - 854us/step
# Epoch 170/500
# 41/41 - 0s - loss: 0.0092 - 34ms/epoch - 830us/step
# Epoch 171/500
# 41/41 - 0s - loss: 0.0092 - 35ms/epoch - 854us/step
# Epoch 172/500
# 41/41 - 0s - loss: 0.0092 - 35ms/epoch - 854us/step
# Epoch 173/500
# 41/41 - 0s - loss: 0.0092 - 33ms/epoch - 806us/step
# Epoch 174/500
# 41/41 - 0s - loss: 0.0092 - 34ms/epoch - 830us/step
# Epoch 175/500
# 41/41 - 0s - loss: 0.0092 - 34ms/epoch - 830us/step
# Epoch 176/500
# 41/41 - 0s - loss: 0.0091 - 34ms/epoch - 830us/step
# Epoch 177/500
# 41/41 - 0s - loss: 0.0092 - 33ms/epoch - 806us/step
# Epoch 178/500
# 41/41 - 0s - loss: 0.0091 - 33ms/epoch - 806us/step
# Epoch 179/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 180/500
# 41/41 - 0s - loss: 0.0091 - 34ms/epoch - 830us/step
# Epoch 181/500
# 41/41 - 0s - loss: 0.0091 - 35ms/epoch - 854us/step
# Epoch 182/500
# 41/41 - 0s - loss: 0.0091 - 34ms/epoch - 830us/step
# Epoch 183/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 184/500
# 41/41 - 0s - loss: 0.0090 - 33ms/epoch - 806us/step
# Epoch 185/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 186/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 187/500
# 41/41 - 0s - loss: 0.0090 - 35ms/epoch - 854us/step
# Epoch 188/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 189/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 190/500
# 41/41 - 0s - loss: 0.0091 - 35ms/epoch - 854us/step
# Epoch 191/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 192/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 193/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 194/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 195/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 196/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 197/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 198/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 199/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 200/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 201/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 202/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 203/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 204/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 205/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 206/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 207/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 208/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 209/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 210/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 211/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 212/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 213/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 214/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 215/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 216/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 217/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 218/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 219/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 220/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 221/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 222/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 223/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 224/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 225/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 226/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 227/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 228/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 229/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 230/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 231/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 232/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 233/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 234/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 235/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 236/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 237/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 238/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 239/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 240/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 241/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 242/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 243/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 244/500
# 41/41 - 0s - loss: 0.0090 - 33ms/epoch - 806us/step
# Epoch 245/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 246/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 247/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 248/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 249/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 250/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 251/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 252/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 253/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 254/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 255/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 256/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 257/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 258/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 259/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 260/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 261/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 262/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 263/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 264/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 265/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 266/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 267/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 268/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 269/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 270/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 271/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 272/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 273/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 274/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 275/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 276/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 277/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 278/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 279/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 280/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 281/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 282/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 283/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 284/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 285/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 286/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 287/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 288/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 289/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 290/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 291/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 292/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 293/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 294/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 295/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 296/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 297/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 298/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 299/500
# 41/41 - 0s - loss: 0.0088 - 36ms/epoch - 879us/step
# Epoch 300/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 301/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 302/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 303/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 304/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 305/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 306/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 307/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 308/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 309/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 310/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 311/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 312/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 313/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 314/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 315/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 316/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 317/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 318/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 319/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 320/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 321/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 322/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 323/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 324/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 325/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 326/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 327/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 328/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 329/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 330/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 331/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 332/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 333/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 334/500
# 41/41 - 0s - loss: 0.0091 - 33ms/epoch - 806us/step
# Epoch 335/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 336/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 337/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 338/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 339/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 340/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 341/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 342/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 343/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 344/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 345/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 346/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 347/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 348/500
# 41/41 - 0s - loss: 0.0091 - 33ms/epoch - 806us/step
# Epoch 349/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 350/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 351/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 352/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 353/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 354/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 355/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 356/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 357/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 358/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 359/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 360/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 361/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 362/500
# 41/41 - 0s - loss: 0.0089 - 36ms/epoch - 879us/step
# Epoch 363/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 364/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 365/500
# 41/41 - 0s - loss: 0.0090 - 35ms/epoch - 854us/step
# Epoch 366/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 367/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 368/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 369/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 370/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 371/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 372/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 373/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 374/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 375/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 376/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 377/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 378/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 379/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 380/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 381/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 382/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 383/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 384/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 385/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 386/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 387/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 388/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 389/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 390/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 391/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 392/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 393/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 394/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 395/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 396/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 397/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 398/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 399/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 400/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 818us/step
# Epoch 401/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 402/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 403/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 404/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 405/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 406/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 407/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 408/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 409/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 410/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 411/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 412/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 413/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 414/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 415/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 416/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 417/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 418/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 419/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 420/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 421/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 422/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 423/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 424/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 425/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 426/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 427/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 428/500
# 41/41 - 0s - loss: 0.0090 - 33ms/epoch - 806us/step
# Epoch 429/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 430/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 431/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 432/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 433/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 434/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 435/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 436/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 437/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 438/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 439/500
# 41/41 - 0s - loss: 0.0090 - 34ms/epoch - 830us/step
# Epoch 440/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 441/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 442/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 443/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 444/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 445/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 446/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 447/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 448/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 449/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 450/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 451/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 452/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 453/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 454/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 455/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 456/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 457/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 458/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 459/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 460/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 461/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 462/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 463/500
# 41/41 - 0s - loss: 0.0087 - 34ms/epoch - 830us/step
# Epoch 464/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 465/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 466/500
# 41/41 - 0s - loss: 0.0089 - 33ms/epoch - 806us/step
# Epoch 467/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 468/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 469/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 470/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 471/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 472/500
# 41/41 - 0s - loss: 0.0088 - 36ms/epoch - 879us/step
# Epoch 473/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 474/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 475/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 476/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 477/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 478/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 479/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 480/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 481/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 482/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 483/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 484/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 485/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 486/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 487/500
# 41/41 - 0s - loss: 0.0088 - 33ms/epoch - 806us/step
# Epoch 488/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 489/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 490/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 491/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 492/500
# 41/41 - 0s - loss: 0.0089 - 35ms/epoch - 854us/step
# Epoch 493/500
# 41/41 - 0s - loss: 0.0089 - 36ms/epoch - 879us/step
# Epoch 494/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 495/500
# 41/41 - 0s - loss: 0.0089 - 34ms/epoch - 830us/step
# Epoch 496/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 497/500
# 41/41 - 0s - loss: 0.0088 - 35ms/epoch - 854us/step
# Epoch 498/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step
# Epoch 499/500
# 41/41 - 0s - loss: 0.0088 - 36ms/epoch - 879us/step
# Epoch 500/500
# 41/41 - 0s - loss: 0.0088 - 34ms/epoch - 830us/step

# %%
# Make predictions

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)


# Invert predictions

trainPredict = np.expm1(trainPredict)
trainY = np.expm1(trainY)
testPredict = np.expm1(testPredict)
testY = np.expm1(testY)


# Calculate root mean squared error

trainScore = math.sqrt(mse(trainY, trainPredict[:, 0]))
print("Train Score: %.2f RMSE" % (trainScore))

testScore = math.sqrt(mse(testY, testPredict[:, 0]))
print("Test Score: %.2f RMSE" % (testScore))
# Out:
# 41/41 [==============================] - 0s 601us/step
# 14/14 [==============================] - 0s 616us/step
# Train Score: 2.36 RMSE
# Test Score: 3.14 RMSE

# %%
test_series = pd.Series(testY)

# State of model performance

if (testScore < test_series.std()):
    print("\n[ Model performance is GOOD enough ]")
    print("\nRMSE of test prediction < Standard deviation of test dataset")
    print("%.2f" % (testScore), ">", "%.2f" % (test_series.std()))
else:
    print("\n[ Model performance is NOT GOOD enough ]")
    print("\nRMSE of test prediction > Standard deviation of test dataset")
    print("%.2f" % (testScore), ">", "%.2f" % (test_series.std()))
# Out:
# [ Model performance is GOOD enough ]
#
# RMSE of test prediction < Standard deviation of test dataset
# 3.14 > 4.40

# %%
# Shift train predictions for plotting

trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict) + look_back, :] = trainPredict


# Shift test predictions for plotting

testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict) + (look_back * 2) + 1:len(dataset) - 1, :] = testPredict


# Plot original dataset and predictions

time_axis = np.linspace(0, dataset.shape[0] - 1, 15)
time_axis = np.array([int(i) for i in time_axis])
time_axisLab = np.array(df2.index, dtype = "datetime64[D]")

fig = plt.figure()
ax = fig.add_axes([0, 0, 2.1, 2])

ax.plot(np.expm1(dataset), label = "Original Dataset")
ax.plot(trainPredictPlot, color = "orange", label = "Train Prediction")
ax.plot(testPredictPlot, color = "red", label = "Test Prediction")
ax.set_xticks(time_axis)
ax.set_xticklabels(time_axisLab[time_axis], rotation = 45)
ax.set_xlabel("\nDate", fontsize = 27, fontweight = "bold")
ax.set_ylabel("ISPU", fontsize = 27, fontweight = "bold")
ax.legend(loc = "best", prop = {"size": 20})
ax.tick_params(size = 10, labelsize = 15)
ax.set_xlim([-1, 1735])

ax1 = fig.add_axes([2.3, 1.3, 1, 0.7])
ax1.plot(np.expm1(dataset), label = "Original Dataset")
ax1.plot(testPredictPlot, color = "red", label = "Test Prediction")
ax1.set_xticks(time_axis)
ax1.set_xticklabels(time_axisLab[time_axis], rotation = 45)
ax1.set_xlabel("Date", fontsize = 27, fontweight = "bold")
ax1.set_ylabel("ISPU", fontsize = 27, fontweight = "bold")
ax1.tick_params(size = 10, labelsize = 15)
ax1.set_xlim([1360, 1735])
# Out:
# (1360.0, 1735.0)
