# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2, MobileNet
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D, ZeroPadding2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model, Sequential

# %%
model = MobileNetV2(weights = "imagenet",
                    include_top = False,
                    input_shape = (200, 200, 3)
                   )
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
for (i, layer) in enumerate(model.layers):
    print(f"{i} {layer.__class__.__name__} {layer.trainable}")
# Out:
# 0 InputLayer True
# 1 Conv2D True
# 2 BatchNormalization True
# 3 ReLU True
# 4 DepthwiseConv2D True
# 5 BatchNormalization True
# 6 ReLU True
# 7 Conv2D True
# 8 BatchNormalization True
# 9 Conv2D True
# 10 BatchNormalization True
# 11 ReLU True
# 12 ZeroPadding2D True
# 13 DepthwiseConv2D True
# 14 BatchNormalization True
# 15 ReLU True
# 16 Conv2D True
# 17 BatchNormalization True
# 18 Conv2D True
# 19 BatchNormalization True
# 20 ReLU True
# 21 DepthwiseConv2D True
# 22 BatchNormalization True
# 23 ReLU True
# 24 Conv2D True
# 25 BatchNormalization True
# 26 Add True
# 27 Conv2D True
# 28 BatchNormalization True
# 29 ReLU True
# 30 ZeroPadding2D True
# 31 DepthwiseConv2D True
# 32 BatchNormalization True
# 33 ReLU True
# 34 Conv2D True
# 35 BatchNormalization True
# 36 Conv2D True
# 37 BatchNormalization True
# 38 ReLU True
# 39 DepthwiseConv2D True
# 40 BatchNormalization True
# 41 ReLU True
# 42 Conv2D True
# 43 BatchNormalization True
# 44 Add True
# 45 Conv2D True
# 46 BatchNormalization True
# 47 ReLU True
# 48 DepthwiseConv2D True
# 49 BatchNormalization True
# 50 ReLU True
# 51 Conv2D True
# 52 BatchNormalization True
# 53 Add True
# 54 Conv2D True
# 55 BatchNormalization True
# 56 ReLU True
# 57 ZeroPadding2D True
# 58 DepthwiseConv2D True
# 59 BatchNormalization True
# 60 ReLU True
# 61 Conv2D True
# 62 BatchNormalization True
# 63 Conv2D True
# 64 BatchNormalization True
# 65 ReLU True
# 66 DepthwiseConv2D True
# 67 BatchNormalization True
# 68 ReLU True
# 69 Conv2D True
# 70 BatchNormalization True
# 71 Add True
# 72 Conv2D True
# 73 BatchNormalization True
# 74 ReLU True
# 75 DepthwiseConv2D True
# 76 BatchNormalization True
# 77 ReLU True
# 78 Conv2D True
# 79 BatchNormalization True
# 80 Add True
# 81 Conv2D True
# 82 BatchNormalization True
# 83 ReLU True
# 84 DepthwiseConv2D True
# 85 BatchNormalization True
# 86 ReLU True
# 87 Conv2D True
# 88 BatchNormalization True
# 89 Add True
# 90 Conv2D True
# 91 BatchNormalization True
# 92 ReLU True
# 93 DepthwiseConv2D True
# 94 BatchNormalization True
# 95 ReLU True
# 96 Conv2D True
# 97 BatchNormalization True
# 98 Conv2D True
# 99 BatchNormalization True
# 100 ReLU True
# 101 DepthwiseConv2D True
# 102 BatchNormalization True
# 103 ReLU True
# 104 Conv2D True
# 105 BatchNormalization True
# 106 Add True
# 107 Conv2D True
# 108 BatchNormalization True
# 109 ReLU True
# 110 DepthwiseConv2D True
# 111 BatchNormalization True
# 112 ReLU True
# 113 Conv2D True
# 114 BatchNormalization True
# 115 Add True
# 116 Conv2D True
# 117 BatchNormalization True
# 118 ReLU True
# 119 ZeroPadding2D True
# 120 DepthwiseConv2D True
# 121 BatchNormalization True
# 122 ReLU True
# 123 Conv2D True
# 124 BatchNormalization True
# 125 Conv2D True
# 126 BatchNormalization True
# 127 ReLU True
# 128 DepthwiseConv2D True
# 129 BatchNormalization True
# 130 ReLU True
# 131 Conv2D True
# 132 BatchNormalization True
# 133 Add True
# 134 Conv2D True
# 135 BatchNormalization True
# 136 ReLU True
# 137 DepthwiseConv2D True
# 138 BatchNormalization True
# 139 ReLU True
# 140 Conv2D True
# 141 BatchNormalization True
# 142 Add True
# 143 Conv2D True
# 144 BatchNormalization True
# 145 ReLU True
# 146 DepthwiseConv2D True
# 147 BatchNormalization True
# 148 ReLU True
# 149 Conv2D True
# 150 BatchNormalization True
# 151 Conv2D True
# 152 BatchNormalization True
# 153 ReLU True

# %%
for layer in model.layers:
    layer.trainable = False

# %%
for (i, layer) in enumerate(model.layers):
    print(f"{i} {layer.__class__.__name__} {layer.trainable}")
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 BatchNormalization False
# 3 ReLU False
# 4 DepthwiseConv2D False
# 5 BatchNormalization False
# 6 ReLU False
# 7 Conv2D False
# 8 BatchNormalization False
# 9 Conv2D False
# 10 BatchNormalization False
# 11 ReLU False
# 12 ZeroPadding2D False
# 13 DepthwiseConv2D False
# 14 BatchNormalization False
# 15 ReLU False
# 16 Conv2D False
# 17 BatchNormalization False
# 18 Conv2D False
# 19 BatchNormalization False
# 20 ReLU False
# 21 DepthwiseConv2D False
# 22 BatchNormalization False
# 23 ReLU False
# 24 Conv2D False
# 25 BatchNormalization False
# 26 Add False
# 27 Conv2D False
# 28 BatchNormalization False
# 29 ReLU False
# 30 ZeroPadding2D False
# 31 DepthwiseConv2D False
# 32 BatchNormalization False
# 33 ReLU False
# 34 Conv2D False
# 35 BatchNormalization False
# 36 Conv2D False
# 37 BatchNormalization False
# 38 ReLU False
# 39 DepthwiseConv2D False
# 40 BatchNormalization False
# 41 ReLU False
# 42 Conv2D False
# 43 BatchNormalization False
# 44 Add False
# 45 Conv2D False
# 46 BatchNormalization False
# 47 ReLU False
# 48 DepthwiseConv2D False
# 49 BatchNormalization False
# 50 ReLU False
# 51 Conv2D False
# 52 BatchNormalization False
# 53 Add False
# 54 Conv2D False
# 55 BatchNormalization False
# 56 ReLU False
# 57 ZeroPadding2D False
# 58 DepthwiseConv2D False
# 59 BatchNormalization False
# 60 ReLU False
# 61 Conv2D False
# 62 BatchNormalization False
# 63 Conv2D False
# 64 BatchNormalization False
# 65 ReLU False
# 66 DepthwiseConv2D False
# 67 BatchNormalization False
# 68 ReLU False
# 69 Conv2D False
# 70 BatchNormalization False
# 71 Add False
# 72 Conv2D False
# 73 BatchNormalization False
# 74 ReLU False
# 75 DepthwiseConv2D False
# 76 BatchNormalization False
# 77 ReLU False
# 78 Conv2D False
# 79 BatchNormalization False
# 80 Add False
# 81 Conv2D False
# 82 BatchNormalization False
# 83 ReLU False
# 84 DepthwiseConv2D False
# 85 BatchNormalization False
# 86 ReLU False
# 87 Conv2D False
# 88 BatchNormalization False
# 89 Add False
# 90 Conv2D False
# 91 BatchNormalization False
# 92 ReLU False
# 93 DepthwiseConv2D False
# 94 BatchNormalization False
# 95 ReLU False
# 96 Conv2D False
# 97 BatchNormalization False
# 98 Conv2D False
# 99 BatchNormalization False
# 100 ReLU False
# 101 DepthwiseConv2D False
# 102 BatchNormalization False
# 103 ReLU False
# 104 Conv2D False
# 105 BatchNormalization False
# 106 Add False
# 107 Conv2D False
# 108 BatchNormalization False
# 109 ReLU False
# 110 DepthwiseConv2D False
# 111 BatchNormalization False
# 112 ReLU False
# 113 Conv2D False
# 114 BatchNormalization False
# 115 Add False
# 116 Conv2D False
# 117 BatchNormalization False
# 118 ReLU False
# 119 ZeroPadding2D False
# 120 DepthwiseConv2D False
# 121 BatchNormalization False
# 122 ReLU False
# 123 Conv2D False
# 124 BatchNormalization False
# 125 Conv2D False
# 126 BatchNormalization False
# 127 ReLU False
# 128 DepthwiseConv2D False
# 129 BatchNormalization False
# 130 ReLU False
# 131 Conv2D False
# 132 BatchNormalization False
# 133 Add False
# 134 Conv2D False
# 135 BatchNormalization False
# 136 ReLU False
# 137 DepthwiseConv2D False
# 138 BatchNormalization False
# 139 ReLU False
# 140 Conv2D False
# 141 BatchNormalization False
# 142 Add False
# 143 Conv2D False
# 144 BatchNormalization False
# 145 ReLU False
# 146 DepthwiseConv2D False
# 147 BatchNormalization False
# 148 ReLU False
# 149 Conv2D False
# 150 BatchNormalization False
# 151 Conv2D False
# 152 BatchNormalization False
# 153 ReLU False

# %%
def add_layer_at_bottom(bottom_model, num_classes):
    top_model = bottom_model.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024, activation = "relu")(top_model)
    top_model = Dense(1024, activation = "relu")(top_model)
    top_model = Dense(512, activation = "relu")(top_model)
    top_model = Dense(num_classes, activation = "softmax")(top_model)
    return top_model

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_data_dir = "data/train"
val_data_dir = "data/test"

# %%
from keras.layers.preprocessing.image_preprocessing import HORIZONTAL

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range = 45,
                                   width_shift_range = 0.3,
                                   height_shift_range = 0.3,
                                   horizontal_flip = True,
                                   fill_mode = "nearest")

val_datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_data_dir,
                                                    target_size = (200, 200),
                                                    batch_size = 32,
                                                    class_mode = "categorical")

val_generator = val_datagen.flow_from_directory(val_data_dir,
                                                    target_size = (200, 200),
                                                    batch_size = 32,
                                                    class_mode = "categorical")
# Out:
# Found 140 images belonging to 4 classes.
# Found 20 images belonging to 4 classes.

# %%
train_class_names = set()
num_train_samples = 0

for i in train_generator.filenames:
    train_class_names.add(i.split('\\')[0])
    num_train_samples += 1
print(num_train_samples)
train_class_names
# Out:
# 140
# {'oval', 'rectangle', 'stickman', 'triangle'}

# %%
val_class_names = set()
num_val_samples = 0

for i in val_generator.filenames:
    val_class_names.add(i.split('\\')[0])
    num_val_samples += 1
print(num_val_samples)
val_class_names
# Out:
# 20
# {'oval', 'rectangle', 'stickman', 'triangle'}

# %%
num_classes = len(train_generator.class_indices)

FC_head = add_layer_at_bottom(model, num_classes)

main_model = Model(inputs = model.input,
                   outputs = FC_head)

main_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 200, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 100, 100, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 100, 100, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 100, 100, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 100, 100, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 100, 100, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 100, 100, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 100, 100, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 100, 100, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 100, 100, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 100, 100, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 100, 100, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 101, 101, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 50, 50, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 50, 50, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 50, 50, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 50, 50, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 50, 50, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 50, 50, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 50, 50, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 50, 50, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 50, 50, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 50, 50, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 50, 50, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 50, 50, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 50, 50, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 50, 50, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 50, 50, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 50, 50, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 50, 50, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 51, 51, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 25, 25, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 25, 25, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 25, 25, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 25, 25, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 25, 25, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 25, 25, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 25, 25, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 25, 25, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 25, 25, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 25, 25, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 25, 25, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 25, 25, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 25, 25, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 25, 25, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 25, 25, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 25, 25, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 25, 25, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 25, 25, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 25, 25, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 25, 25, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 25, 25, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 25, 25, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 25, 25, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 25, 25, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 25, 25, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 25, 25, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 27, 27, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 13, 13, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 13, 13, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 13, 13, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 13, 13, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 13, 13, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 13, 13, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 13, 13, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 13, 13, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 13, 13, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 13, 13, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 13, 13, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 13, 13, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 13, 13, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 13, 13, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 13, 13, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 13, 13, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 13, 13, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 13, 13, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 13, 13, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 13, 13, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 13, 13, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 13, 13, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 13, 13, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 13, 13, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 13, 13, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 13, 13, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 13, 13, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 13, 13, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 13, 13, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 13, 13, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 13, 13, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 13, 13, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 13, 13, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 13, 13, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 13, 13, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 13, 13, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 13, 13, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 13, 13, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 13, 13, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 13, 13, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 13, 13, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 13, 13, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 13, 13, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 13, 13, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 13, 13, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 13, 13, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 13, 13, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 13, 13, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 13, 13, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 13, 13, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 13, 13, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 13, 13, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 13, 13, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 13, 13, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 13, 13, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 13, 13, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 13, 13, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 13, 13, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 13, 13, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 13, 13, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 13, 13, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['out_relu[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1024)         1311744     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 1024)         1049600     ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 512)          524800      ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 4)            2052        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 5,146,180
# Trainable params: 2,888,196
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
checkpoint = ModelCheckpoint("Shape_recognition.h5",
                             monitor = "loss",
                             mode = "min",
                             save_best_only = True, verbose = 1)

earlystop = EarlyStopping(monitor = "loss",
                          min_delta = 0,
                          patience = 50,
                          verbose = 1, 
                          restore_best_weights = True)

callbacks = [checkpoint, earlystop]

main_model.compile(loss = "categorical_crossentropy",
                   optimizer = RMSprop(learning_rate = 0.001),
                   metrics = ["accuracy"])

epochs = 50
batch_size = 32

history = main_model.fit(train_generator,
                         steps_per_epoch = num_train_samples // batch_size,
                         epochs = epochs,
                         callbacks = callbacks,
                         validation_data = val_generator,
                         validation_steps = num_val_samples // batch_size)
# Out:
# Epoch 1/50
# 4/4 [==============================] - ETA: 0s - loss: 10.2208 - accuracy: 0.2685
# Epoch 1: loss improved from inf to 10.22083, saving model to Shape_recognition.h5
# 4/4 [==============================] - 4s 381ms/step - loss: 10.2208 - accuracy: 0.2685
# Epoch 2/50
# 4/4 [==============================] - ETA: 0s - loss: 1.2136 - accuracy: 0.5370
# Epoch 2: loss improved from 10.22083 to 1.21363, saving model to Shape_recognition.h5
# 4/4 [==============================] - 1s 357ms/step - loss: 1.2136 - accuracy: 0.5370
# Epoch 3/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3941 - accuracy: 0.8148
# Epoch 3: loss improved from 1.21363 to 0.39412, saving model to Shape_recognition.h5
# 4/4 [==============================] - 1s 443ms/step - loss: 0.3941 - accuracy: 0.8148
# Epoch 4/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2706 - accuracy: 0.8796
# Epoch 4: loss improved from 0.39412 to 0.27056, saving model to Shape_recognition.h5
# 4/4 [==============================] - 1s 358ms/step - loss: 0.2706 - accuracy: 0.8796
# Epoch 5/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9219
# Epoch 5: loss improved from 0.27056 to 0.21037, saving model to Shape_recognition.h5
# 4/4 [==============================] - 2s 429ms/step - loss: 0.2104 - accuracy: 0.9219
# Epoch 6/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9907
# Epoch 6: loss improved from 0.21037 to 0.06553, saving model to Shape_recognition.h5
# 4/4 [==============================] - 1s 349ms/step - loss: 0.0655 - accuracy: 0.9907
# Epoch 7/50
# 4/4 [==============================] - ETA: 0s - loss: 0.5853 - accuracy: 0.8241
# Epoch 7: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 276ms/step - loss: 0.5853 - accuracy: 0.8241
# Epoch 8/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9815
# Epoch 8: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1358 - accuracy: 0.9815
# Epoch 9/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1976 - accuracy: 0.9167
# Epoch 9: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 267ms/step - loss: 0.1976 - accuracy: 0.9167
# Epoch 10/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9375
# Epoch 10: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 361ms/step - loss: 0.1260 - accuracy: 0.9375
# Epoch 11/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1554 - accuracy: 0.9453
# Epoch 11: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 360ms/step - loss: 0.1554 - accuracy: 0.9453
# Epoch 12/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2705 - accuracy: 0.9259
# Epoch 12: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 275ms/step - loss: 0.2705 - accuracy: 0.9259
# Epoch 13/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.9688
# Epoch 13: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 368ms/step - loss: 0.0814 - accuracy: 0.9688
# Epoch 14/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2674 - accuracy: 0.9167
# Epoch 14: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 276ms/step - loss: 0.2674 - accuracy: 0.9167
# Epoch 15/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9141
# Epoch 15: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 358ms/step - loss: 0.1943 - accuracy: 0.9141
# Epoch 16/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2035 - accuracy: 0.9297
# Epoch 16: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 363ms/step - loss: 0.2035 - accuracy: 0.9297
# Epoch 17/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7392 - accuracy: 0.7778
# Epoch 17: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 371ms/step - loss: 0.7392 - accuracy: 0.7778
# Epoch 18/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1572 - accuracy: 0.9352
# Epoch 18: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 265ms/step - loss: 0.1572 - accuracy: 0.9352
# Epoch 19/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 0.9352
# Epoch 19: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1696 - accuracy: 0.9352
# Epoch 20/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9375
# Epoch 20: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 355ms/step - loss: 0.2109 - accuracy: 0.9375
# Epoch 21/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9259
# Epoch 21: loss did not improve from 0.06553
# 4/4 [==============================] - 1s 280ms/step - loss: 0.2291 - accuracy: 0.9259
# Epoch 22/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9907
# Epoch 22: loss improved from 0.06553 to 0.04779, saving model to Shape_recognition.h5
# 4/4 [==============================] - 1s 348ms/step - loss: 0.0478 - accuracy: 0.9907
# Epoch 23/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1368 - accuracy: 0.9531
# Epoch 23: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 359ms/step - loss: 0.1368 - accuracy: 0.9531
# Epoch 24/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9074
# Epoch 24: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1880 - accuracy: 0.9074
# Epoch 25/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3316 - accuracy: 0.8889
# Epoch 25: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 280ms/step - loss: 0.3316 - accuracy: 0.8889
# Epoch 26/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.8981
# Epoch 26: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 369ms/step - loss: 0.1877 - accuracy: 0.8981
# Epoch 27/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1672 - accuracy: 0.9537
# Epoch 27: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1672 - accuracy: 0.9537
# Epoch 28/50
# 4/4 [==============================] - ETA: 0s - loss: 0.4736 - accuracy: 0.9259
# Epoch 28: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 274ms/step - loss: 0.4736 - accuracy: 0.9259
# Epoch 29/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0762 - accuracy: 0.9630
# Epoch 29: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0762 - accuracy: 0.9630
# Epoch 30/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0566 - accuracy: 0.9844
# Epoch 30: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 361ms/step - loss: 0.0566 - accuracy: 0.9844
# Epoch 31/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1106 - accuracy: 0.9352
# Epoch 31: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 371ms/step - loss: 0.1106 - accuracy: 0.9352
# Epoch 32/50
# 4/4 [==============================] - ETA: 0s - loss: 0.5355 - accuracy: 0.8889
# Epoch 32: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 279ms/step - loss: 0.5355 - accuracy: 0.8889
# Epoch 33/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1111 - accuracy: 0.9444
# Epoch 33: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 265ms/step - loss: 0.1111 - accuracy: 0.9444
# Epoch 34/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.9167
# Epoch 34: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 269ms/step - loss: 0.2988 - accuracy: 0.9167
# Epoch 35/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9630
# Epoch 35: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 266ms/step - loss: 0.0796 - accuracy: 0.9630
# Epoch 36/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9722
# Epoch 36: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0610 - accuracy: 0.9722
# Epoch 37/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9609
# Epoch 37: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 360ms/step - loss: 0.1495 - accuracy: 0.9609
# Epoch 38/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1698 - accuracy: 0.9352
# Epoch 38: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 375ms/step - loss: 0.1698 - accuracy: 0.9352
# Epoch 39/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1104 - accuracy: 0.9537
# Epoch 39: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 367ms/step - loss: 0.1104 - accuracy: 0.9537
# Epoch 40/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9259
# Epoch 40: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 265ms/step - loss: 0.2082 - accuracy: 0.9259
# Epoch 41/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3033 - accuracy: 0.8796
# Epoch 41: loss did not improve from 0.04779
# 4/4 [==============================] - 1s 284ms/step - loss: 0.3033 - accuracy: 0.8796
# Epoch 42/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9815
# Epoch 42: loss improved from 0.04779 to 0.02764, saving model to Shape_recognition.h5
# 4/4 [==============================] - 1s 361ms/step - loss: 0.0276 - accuracy: 0.9815
# Epoch 43/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0852 - accuracy: 0.9722
# Epoch 43: loss did not improve from 0.02764
# 4/4 [==============================] - 1s 279ms/step - loss: 0.0852 - accuracy: 0.9722
# Epoch 44/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9630
# Epoch 44: loss did not improve from 0.02764
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1795 - accuracy: 0.9630
# Epoch 45/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3844 - accuracy: 0.9219
# Epoch 45: loss did not improve from 0.02764
# 4/4 [==============================] - 1s 370ms/step - loss: 0.3844 - accuracy: 0.9219
# Epoch 46/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9688
# Epoch 46: loss did not improve from 0.02764
# 4/4 [==============================] - 1s 361ms/step - loss: 0.0617 - accuracy: 0.9688
# Epoch 47/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1782 - accuracy: 0.9352
# Epoch 47: loss did not improve from 0.02764
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1782 - accuracy: 0.9352
# Epoch 48/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9537
# Epoch 48: loss did not improve from 0.02764
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1255 - accuracy: 0.9537
# Epoch 49/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9766
# Epoch 49: loss did not improve from 0.02764
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0518 - accuracy: 0.9766
# Epoch 50/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2518 - accuracy: 0.9352
# Epoch 50: loss did not improve from 0.02764
# 4/4 [==============================] - 1s 284ms/step - loss: 0.2518 - accuracy: 0.9352

# %%
import sys
# !{sys.executable} -m pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\chris\miniconda3\envs\core\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\chris\miniconda3\envs\core\lib\site-packages (from opencv-python) (1.24.3)

# %%
import cv2

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from PIL import Image

test_image = "data/validation/stickman/001.jpg"

# Load image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image_to_tensor = tf.convert_to_tensor(np.array(image))
    return image, tf.expand_dims(image_to_tensor, axis = 0)



preprocess_image(test_image)

# Predict using the model
def predict(model, image_tensor):
    res = model.predict(image_tensor)
    model.evaluate(res)
    with tf.no_gradient():
        outputs = model(image_tensor)
        probabilities = tf.nn.softmax(outputs, axis = 1)
    return probabilities.cpu().numpy().flatten()


# Visualization method
def visualize_predictions(image, probabilities, class_names):
    fig, axarr = plt.subplots(1, 2, figsize = (14, 7))

    # Display image
    axarr[0].imshow(img)
    axarr[0].axis("off")

    # Display predictions
    axarr[1].barh(class_names, probabilities)
    axarr[1].set_xlabel("Probability")
    axarr[1].set_title("Class Predictions")
    axarr[1].set_xlim(0, 1)

    plt.tight_layout()

    plt.show()

# Class names
classes = ["Oval", "Rectangle", "Stickman", "Triangle"]

# img = cv2.imread("data/validation/stickman/005.jpg")
# plt.imshow(img)
# img = img.reshape(1, 200, 200, 3)
# res = main_model.predict(img)
# out[np.argmax(res)]

original_image, image_tensor = preprocess_image(test_image)
print(predict(main_model, image_tensor))

# probabilities = predict(main_model(input_shape = (200, 200, 3), image_tensor)

# visualize_predictions(original_image, probabilities, classes)
# Out:
# 1/1 [==============================] - 1s 734ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 56
#      49 # img = cv2.imread("data/validation/stickman/005.jpg")
#      50 # plt.imshow(img)
#      51 # img = img.reshape(1, 200, 200, 3)
#      52 # res = main_model.predict(img)
#      53 # out[np.argmax(res)]
#      55 original_image, image_tensor = preprocess_image(test_image)
# ---> 56 print(predict(main_model, image_tensor))
#
# Cell In[18], line 21, in predict(model, image_tensor)
#      19 def predict(model, image_tensor):
#      20     res = model.predict(image_tensor)
# ---> 21     model.evaluate(res)
#      22     with tf.no_gradient():
#      23         outputs = model(image_tensor)
#
# File ~\miniconda3\envs\core\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filer5yd_sy2.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__test_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\Chris\miniconda3\envs\core\lib\site-packages\keras\engine\training.py", line 1727, in test_function  *
#         return step_function(self, iterator)
#     File "C:\Users\Chris\miniconda3\envs\core\lib\site-packages\keras\engine\training.py", line 1713, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Chris\miniconda3\envs\core\lib\site-packages\keras\engine\training.py", line 1701, in run_step  **
#         outputs = model.test_step(data)
#     File "C:\Users\Chris\miniconda3\envs\core\lib\site-packages\keras\engine\training.py", line 1665, in test_step
#         y_pred = self(x, training=False)
#     File "C:\Users\Chris\miniconda3\envs\core\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Chris\miniconda3\envs\core\lib\site-packages\keras\engine\input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "model" is incompatible with the layer: expected shape=(None, 200, 200, 3), found shape=(None, 4)

# %%
history.history??
# Out:
# Type:        dict
# String form: {'loss': [10.220826148986816, 1.2136305570602417, 0.39411869645118713, 0.2705601155757904, 0.21037301421165466, 0.06552980095148087, 0.5853488445281982, 0.13581886887550354, 0.19756267964839935, 0.1260077953338623, 0.15543457865715027, 0.270478218793869, 0.08144499361515045, 0.2673841118812561, 0.19431203603744507, 0.20352140069007874, 0.739203691482544, 0.15722663700580597, 0.1696263551712036, 0.21093714237213135, 0.22907043993473053, 0.04779376462101936, 0.1368158757686615, 0.18802303075790405, 0.3316175043582916, 0.18769870698451996, 0.16724614799022675, 0.4736417233943939, 0.07621007412672043, 0.05656179413199425, 0.11056617647409439, 0.5354960560798645, 0.11113449186086655, 0.29879727959632874, 0.0795845165848732, 0.06096518412232399, 0.14953932166099548, 0.16976779699325562, 0.11037415266036987, 0.20818611979484558, 0.30325639247894287, 0.027643993496894836, 0.08518331497907639, 0.17947949469089508, 0.38437420129776, 0.061682283878326416, 0.17820680141448975, 0.12545686960220337, 0.05176420137286186, 0.2517566382884979], 'accuracy': [0.26851850748062134, 0.5370370149612427, 0.8148148059844971, 0.8796296119689941, 0.921875, 0.9907407164573669, 0.8240740895271301, 0.9814814925193787, 0.9166666865348816, 0.9375, 0.9453125, 0.9259259104728699, 0.96875, 0.9166666865348816, 0.9140625, 0.9296875, 0.7777777910232544, 0.9351851940155029, 0.9351851940155029, 0.9375, 0.9259259104728699, 0.9907407164573669, 0.953125, 0.9074074029922485, 0.8888888955116272, 0.8981481194496155, 0.9537037014961243, 0.9259259104728699, 0.9629629850387573, 0.984375, 0.9351851940155029, 0.8888888955116272, 0.9444444179534912, 0.9166666865348816, 0.9629629850387573, 0.9722222089767456, 0.9609375, 0.9351851940155029, 0.9537037014961243, 0.9259259104728699, 0.8796296119689941, 0.9814814925193787, 0.9722222089767456, 0.9629629850387573, 0.921875, 0.96875, 0.9351851940155029, 0.9537037014961243, 0.9765625, 0.9351851940155029]}
# Length:      2
# Docstring:
# dict() -> new empty dictionary
# dict(mapping) -> new dictionary initialized from a mapping object's
#     (key, value) pairs
# dict(iterable) -> new dictionary initialized as if via:
#     d = {}
#     for k, v in iterable:
#         d[k] = v
# dict(**kwargs) -> new dictionary initialized with the name=value pairs
#     in the keyword argument list.  For example:  dict(one=1, two=2)
